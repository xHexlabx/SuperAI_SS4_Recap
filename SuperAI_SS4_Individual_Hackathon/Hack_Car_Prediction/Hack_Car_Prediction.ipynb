# %% [markdown]
# # SuperAI Season 4 - Level Individual Hackathon - Hack_Car_Prediction

# %% [markdown]
# ## Explore Data

# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('./datasets/train.csv' , index_col = 'Id')
train_target = pd.read_csv('./datasets/train_target.csv' , index_col = 'Id')
test_df = pd.read_csv('./datasets/test.csv', index_col = 'Id')
# Out:
# C:\Users\teehe\AppData\Local\Temp\ipykernel_18856\1359795095.py:1: DtypeWarning: Columns (12,28,29,30,116,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv('./datasets/train.csv' , index_col = 'Id')
# C:\Users\teehe\AppData\Local\Temp\ipykernel_18856\1359795095.py:3: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_df = pd.read_csv('./datasets/test.csv', index_col = 'Id')

# %%
train_df
# Out:
#        Area          SubDistrict                  District         Province  \
# Id
# 0         1              หนองบอน                    ประเวศ         กรุงเทพฯ
# 1         2  เทศบาลตำบลนครชัยศรี                 นครชัยศรี           นครปฐม
# 2         1              บางซื่อ                   บางซื่อ         กรุงเทพฯ
# 3         2              หาดใหญ่          เทศบาลนครหาดใหญ่            สงขลา
# 4         2              ในเมือง        เทศบาลเมืองบ้านไผ่          ขอนแก่น
# ...     ...                  ...                       ...              ...
# 20961     2            หอรัตนไชย  เทศบาลนครพระนครศรีอยุธยา  พระนครศรีอยุธยา
# 20962     2              ในเมือง        เทศบาลเมืองหนองคาย          หนองคาย
# 20963     2             พนัสนิคม       เทศบาลเมืองพนัสนิคม           ชลบุรี
# 20964     2              ในเมือง    เทศบาลเมืองบุรีรัมย์_1        บุรีรัมย์
# 20965     2     เทศบาลตำบลไม้งาม                  เมืองตาก              ตาก
#
#        Region  Q1_OccStatus                       Q1_Occ Q1_OccCode Q1_OccInd  \
# Id
# 0           1             3           รับจ้างทำความสะอาด        L15         L
# 1           2             1                    ขายทอดมัน         D4         D
# 2           1             3  รับจ้างขายสลากกินแบ่งรัฐบาล         D4         D
# 3           5             3           รับจ้างงานก่อสร้าง         C3         C
# 4           4             3      รับทำความสะอาดบ้านอาคาร        L15         L
# ...       ...           ...                          ...        ...       ...
# 20961       2             1                     ขายผักสด         D4         D
# 20962       4             1                    ขายไก่ทอด         D4         D
# 20963       2             1                  ขายเสื้อผ้า         D3         D
# 20964       4             1               นวดเพื่อสุขภาพ         P3         P
# 20965       3             1             เช่าเครื่องเสียง        L10         L
#
#       Q1_IndBD_1  ... Line_Level Moblie  Facebook  Instragram  Tiktok  \
# Id                ...
# 0            888  ...        888      1         0           0       0
# 1            BD1  ...        888      0         0           0       0
# 2           BD26  ...        888      1         0           0       0
# 3            888  ...        888      0         0           0       0
# 4            888  ...        888      0         0           0       0
# ...          ...  ...        ...    ...       ...         ...     ...
# 20961        BD1  ...          2    888       888         888     888
# 20962        BD1  ...        888      0         0           0       0
# 20963        BD5  ...          5    888       888         888     888
# 20964        888  ...        888      1         0           0       0
# 20965        888  ...          5    888       888         888     888
#
#        Youtube  Twitter  OtherApp  OtherAppSpec  NoSocial
# Id
# 0            0        0         0           888         0
# 1            0        0         0           888         1
# 2            0        0         0           888         0
# 3            0        0         0           888         1
# 4            0        0         0           888         1
# ...        ...      ...       ...           ...       ...
# 20961      888      888       888           888       888
# 20962        0        0         0           888         1
# 20963      888      888       888           888       888
# 20964        0        0         0           888         0
# 20965      888      888       888           888       888
#
# [20966 rows x 143 columns]

# %%
def apply_features(row) : 
    
    for col in train_df.columns :
        
        if row[col] == 888 or row[col] == 999 or row[col] == '888' or row[col] == '999':
            
            row[col] = np.nan
    
    return row

# %%
train_df = train_df.apply(apply_features , axis = 1)
test_df = test_df.apply(apply_features , axis = 1)

# %%
train_df
# Out:
#        Area          SubDistrict                  District         Province  \
# Id
# 0         1              หนองบอน                    ประเวศ         กรุงเทพฯ
# 1         2  เทศบาลตำบลนครชัยศรี                 นครชัยศรี           นครปฐม
# 2         1              บางซื่อ                   บางซื่อ         กรุงเทพฯ
# 3         2              หาดใหญ่          เทศบาลนครหาดใหญ่            สงขลา
# 4         2              ในเมือง        เทศบาลเมืองบ้านไผ่          ขอนแก่น
# ...     ...                  ...                       ...              ...
# 20961     2            หอรัตนไชย  เทศบาลนครพระนครศรีอยุธยา  พระนครศรีอยุธยา
# 20962     2              ในเมือง        เทศบาลเมืองหนองคาย          หนองคาย
# 20963     2             พนัสนิคม       เทศบาลเมืองพนัสนิคม           ชลบุรี
# 20964     2              ในเมือง    เทศบาลเมืองบุรีรัมย์_1        บุรีรัมย์
# 20965     2     เทศบาลตำบลไม้งาม                  เมืองตาก              ตาก
#
#        Region  Q1_OccStatus                       Q1_Occ Q1_OccCode Q1_OccInd  \
# Id
# 0           1             3           รับจ้างทำความสะอาด        L15         L
# 1           2             1                    ขายทอดมัน         D4         D
# 2           1             3  รับจ้างขายสลากกินแบ่งรัฐบาล         D4         D
# 3           5             3           รับจ้างงานก่อสร้าง         C3         C
# 4           4             3      รับทำความสะอาดบ้านอาคาร        L15         L
# ...       ...           ...                          ...        ...       ...
# 20961       2             1                     ขายผักสด         D4         D
# 20962       4             1                    ขายไก่ทอด         D4         D
# 20963       2             1                  ขายเสื้อผ้า         D3         D
# 20964       4             1               นวดเพื่อสุขภาพ         P3         P
# 20965       3             1             เช่าเครื่องเสียง        L10         L
#
#       Q1_IndBD_1  ... Line_Level Moblie  Facebook  Instragram  Tiktok  \
# Id                ...
# 0            NaN  ...        NaN    1.0       0.0         0.0     0.0
# 1            BD1  ...        NaN    0.0       0.0         0.0     0.0
# 2           BD26  ...        NaN    1.0       0.0         0.0     0.0
# 3            NaN  ...        NaN    0.0       0.0         0.0     0.0
# 4            NaN  ...        NaN    0.0       0.0         0.0     0.0
# ...          ...  ...        ...    ...       ...         ...     ...
# 20961        BD1  ...        2.0    NaN       NaN         NaN     NaN
# 20962        BD1  ...        NaN    0.0       0.0         0.0     0.0
# 20963        BD5  ...        5.0    NaN       NaN         NaN     NaN
# 20964        NaN  ...        NaN    1.0       0.0         0.0     0.0
# 20965        NaN  ...        5.0    NaN       NaN         NaN     NaN
#
#        Youtube  Twitter  OtherApp  OtherAppSpec  NoSocial
# Id
# 0          0.0      0.0       0.0           NaN       0.0
# 1          0.0      0.0       0.0           NaN       1.0
# 2          0.0      0.0       0.0           NaN       0.0
# 3          0.0      0.0       0.0           NaN       1.0
# 4          0.0      0.0       0.0           NaN       1.0
# ...        ...      ...       ...           ...       ...
# 20961      NaN      NaN       NaN           NaN       NaN
# 20962      0.0      0.0       0.0           NaN       1.0
# 20963      NaN      NaN       NaN           NaN       NaN
# 20964      0.0      0.0       0.0           NaN       0.0
# 20965      NaN      NaN       NaN           NaN       NaN
#
# [20966 rows x 143 columns]

# %% [markdown]
# ## AutoGluon

# %%
from autogluon.tabular import TabularPredictor

# %%
label = 'Predicted'

# %%
predictor = TabularPredictor(label = label , eval_metric='accuracy').fit(train_df.join(train_target))
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240621_155138"
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (20966 samples, 53.31 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels\ag-20240621_155138"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          16
# Memory Avail:       2.14 GB / 15.28 GB (14.0%)
# Disk Space Avail:   487.32 GB / 952.03 GB (51.2%)
# ===================================================
# Train Data Rows:    20966
# Train Data Columns: 143
# Label Column:       Predicted
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    2210.66 MB
# 	Train Data (Original)  Memory Usage: 50.02 MB (2.3% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 37 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['Q5_5B']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['Q5_5B']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 49 | ['Q1_Occ_Year', 'Q1_OCC_A_Month', 'Q1_OCC_B_Num', 'Q1_Occ_Have', 'Q2_OccNum', ...]
# 		('int', [])    : 61 | ['Area', 'Region', 'Q1_OccStatus', 'Q1_OCC_A', 'Q1_OCC_B', ...]
# 		('object', []) : 32 | ['SubDistrict', 'District', 'Province', 'Q1_Occ', 'Q1_OccCode', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 32 | ['SubDistrict', 'District', 'Province', 'Q1_Occ', 'Q1_OccCode', ...]
# 		('float', [])     : 49 | ['Q1_Occ_Year', 'Q1_OCC_A_Month', 'Q1_OCC_B_Num', 'Q1_Occ_Have', 'Q2_OccNum', ...]
# 		('int', [])       : 24 | ['Area', 'Region', 'Q1_OccStatus', 'Q4_4', 'Q4_6', ...]
# 		('int', ['bool']) : 37 | ['Q1_OCC_A', 'Q1_OCC_B', 'Q1_OCC_C', 'Q2', 'Q3No', ...]
# 	1.5s = Fit runtime
# 	142 features in original data used to generate 142 features in processed data.
# 	Train Data (Processed) Memory Usage: 13.17 MB (0.6% of available memory)
# Data preprocessing and feature engineering runtime = 1.55s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 18869, Val Rows: 2097
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.7015	 = Validation score   (accuracy)
# 	0.03s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.6943	 = Validation score   (accuracy)
# 	0.05s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.794	 = Validation score   (accuracy)
# 	0.98s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.7911	 = Validation score   (accuracy)
# 	1.1s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.7868	 = Validation score   (accuracy)
# 	1.39s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.7825	 = Validation score   (accuracy)
# 	1.55s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.7978	 = Validation score   (accuracy)
# 	131.37s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.7735	 = Validation score   (accuracy)
# 	1.28s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.7725	 = Validation score   (accuracy)
# 	1.41s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 4: early stopping
# 	0.7606	 = Validation score   (accuracy)
# 	28.89s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.7959	 = Validation score   (accuracy)
# 	2.89s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.7577	 = Validation score   (accuracy)
# 	33.24s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.7954	 = Validation score   (accuracy)
# 	2.25s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'LightGBMXT': 0.25, 'LightGBMLarge': 0.25, 'LightGBM': 0.125, 'CatBoost': 0.125, 'ExtraTreesGini': 0.125, 'ExtraTreesEntr': 0.062, 'XGBoost': 0.062}
# 	0.8064	 = Validation score   (accuracy)
# 	0.08s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 209.94s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240621_155138")

# %%
predictor.refit_full()
# Out:
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: KNeighborsUnif_FULL ...
# 	0.05s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: KNeighborsDist_FULL ...
# 	0.04s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_FULL ...
# 	0.8s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_FULL ...
# 	0.76s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: RandomForestGini_FULL ...
# 	1.84s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: RandomForestEntr_FULL ...
# 	1.6s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_FULL ...
# 	106.63s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: ExtraTreesGini_FULL ...
# 	1.4s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: ExtraTreesEntr_FULL ...
# 	1.39s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	5.96s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_FULL ...
# 	0.66s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_FULL ...
# 	9.39s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_FULL ...
# 	1.24s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'LightGBMXT': 0.25, 'LightGBMLarge': 0.25, 'LightGBM': 0.125, 'CatBoost': 0.125, 'ExtraTreesGini': 0.125, 'ExtraTreesEntr': 0.062, 'XGBoost': 0.062}
# 	0.08s	 = Training   runtime
# Updated best model to "WeightedEnsemble_L2_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "WeightedEnsemble_L2_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 137.84s ... Best model: "WeightedEnsemble_L2_FULL"
# {'KNeighborsUnif': 'KNeighborsUnif_FULL',
#  'KNeighborsDist': 'KNeighborsDist_FULL',
#  'LightGBMXT': 'LightGBMXT_FULL',
#  'LightGBM': 'LightGBM_FULL',
#  'RandomForestGini': 'RandomForestGini_FULL',
#  'RandomForestEntr': 'RandomForestEntr_FULL',
#  'CatBoost': 'CatBoost_FULL',
#  'ExtraTreesGini': 'ExtraTreesGini_FULL',
#  'ExtraTreesEntr': 'ExtraTreesEntr_FULL',
#  'NeuralNetFastAI': 'NeuralNetFastAI_FULL',
#  'XGBoost': 'XGBoost_FULL',
#  'NeuralNetTorch': 'NeuralNetTorch_FULL',
#  'LightGBMLarge': 'LightGBMLarge_FULL',
#  'WeightedEnsemble_L2': 'WeightedEnsemble_L2_FULL'}

# %%
predictor.fit_pseudolabel(test_df)
# Out:
# Given test_data for pseudo labeling did not contain labels. AutoGluon will assign pseudo labels to data and use it for extra training data...
# Beginning iteration 1 of pseudolabeling out of max 3
# Pseudolabeling algorithm confidently assigned pseudolabels to 78 rows of data on iteration 1. Adding to train data
# C:\Users\teehe\AppData\Roaming\Python\Python311\site-packages\autogluon\tabular\predictor\predictor.py:1761: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pseudo_data[self.label] = y_pseudo_og
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_PSEUDO_1 ...
# 	0.7015	 = Validation score   (accuracy)
# 	0.06s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist_PSEUDO_1 ...
# 	0.6938	 = Validation score   (accuracy)
# 	0.06s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT_PSEUDO_1 ...
# 	0.8045	 = Validation score   (accuracy)
# 	1.48s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_PSEUDO_1 ...
# 	0.7897	 = Validation score   (accuracy)
# 	1.25s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_PSEUDO_1 ...
# 	0.7916	 = Validation score   (accuracy)
# 	1.25s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestEntr_PSEUDO_1 ...
# 	0.7845	 = Validation score   (accuracy)
# 	1.26s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost_PSEUDO_1 ...
# 	0.7973	 = Validation score   (accuracy)
# 	132.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_PSEUDO_1 ...
# 	0.7778	 = Validation score   (accuracy)
# 	1.33s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesEntr_PSEUDO_1 ...
# 	0.7725	 = Validation score   (accuracy)
# 	1.19s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_PSEUDO_1 ...
# No improvement since epoch 2: early stopping
# 	0.7678	 = Validation score   (accuracy)
# 	25.57s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: XGBoost_PSEUDO_1 ...
# 	0.7949	 = Validation score   (accuracy)
# 	3.38s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_PSEUDO_1 ...
# 	0.7682	 = Validation score   (accuracy)
# 	40.48s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBMLarge_PSEUDO_1 ...
# 	0.794	 = Validation score   (accuracy)
# 	2.36s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2_PSEUDO_1 ...
# 	Ensemble Weights: {'LightGBMXT_PSEUDO_1': 0.636, 'CatBoost_PSEUDO_1': 0.136, 'LightGBMLarge_PSEUDO_1': 0.136, 'LightGBM_PSEUDO_1': 0.091}
# 	0.8073	 = Validation score   (accuracy)
# 	0.08s	 = Training   runtime
# 	0.0s	 = Validation runtime
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240621_155138")
# Pseudolabeling algorithm changed validation score from: 0.8063900810681927, to: 0.8063900810681927 using evaluation metric: accuracy

# %%
prediction = predictor.predict(test_df)

# %%
prediction
# Out:
# Id
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 5195    1
# 5196    0
# 5197    0
# 5198    1
# 5199    1
# Name: Predicted, Length: 5200, dtype: int64

# %%
features_importance = predictor.feature_importance(train_df.join(train_target))
features_importance
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['Q5_5B']
# Computing feature importance via permutation shuffling for 142 features using 5000 rows with 5 shuffle sets...
# 	622.56s	= Expected runtime (124.51s per shuffle set)
# 	151.4s	= Actual runtime (Completed 5 of 5 shuffle sets)
#               importance    stddev       p_value  n  p99_high   p99_low
# Salary           0.03652  0.002047  1.180546e-06  5  0.040736  0.032304
# Sex              0.03612  0.004014  1.800411e-05  5  0.044385  0.027855
# District         0.02732  0.002806  1.316273e-05  5  0.033097  0.021543
# Age              0.02648  0.001230  5.563720e-07  5  0.029012  0.023948
# Q1_Occ           0.02060  0.001817  7.182086e-06  5  0.024340  0.016860
# ...                  ...       ...           ... ..       ...       ...
# Q2.2_Occ         0.00000  0.000000  5.000000e-01  5  0.000000  0.000000
# Q2.2_OccCode     0.00000  0.000000  5.000000e-01  5  0.000000  0.000000
# Q10.2_5          0.00000  0.000000  5.000000e-01  5  0.000000  0.000000
# LiveOther        0.00000  0.000000  5.000000e-01  5  0.000000  0.000000
# Q10.1_5         -0.00004  0.000089  8.130495e-01  5  0.000144 -0.000224
#
# [142 rows x 6 columns]

# %%
features_importance.to_csv('./features/features.csv')

# %%
submission_path = './submissions'
prediction.to_csv(f'{submission_path}/submission_refit.csv')
