# %% [markdown]
# # SuperAI Season 4 - Level Individual Hackathon - Sleep Stages Classification <br> Autoencoder

# %% [markdown]
# ## Load data from database

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
from tqdm.notebook import tqdm

# %%
with open ('./database/arrays.npy' , 'rb') as file :

    arrays = np.load(file)

with open ('./database/labels.npy' , 'rb') as file :

    labels = np.load(file)

# %%
print(arrays.shape , labels.shape)
# Out:
# (66607, 15360) (66607,)

# %%
id2label = {
    0 : 'W' ,
    1 : 'N' ,
    2 : 'R'
}
label2id = {
    'W' : 0 ,
    'N' : 1 ,
    'R' : 2
}

# %% [markdown]
# ## Sleep Stages Dataset

# %%
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader , random_split
from torch.utils.data import Dataset
import torchmetrics
import lightning as L
from lightning.pytorch import Trainer
from lightning.pytorch.callbacks import ModelCheckpoint

# %%
class sleep_stages_dataset (Dataset) :

    def __init__ (self , train_path , label_path , transform = None , target_transform = None) :

        self.train_path = train_path
        self.label_path = label_path

        with open (train_path , 'rb') as file :

            self.train_arrays = np.load(file)

        with open (label_path , 'rb') as file :

            self.label_arrays = np.load(file)

        self.transform = transform
        self.target_transform = target_transform

    def __len__(self) :

        return self.train_arrays.shape[0]

    def __getitem__ (self , idx) :

        data  = self.train_arrays[idx]
        label = self.label_arrays[idx]

        if self.transform :

            data = self.transform(data)

        if self.target_transform :

            label = self.target_transform(int(label))

        return data , label

# %%
class OneHotEncodeTransform:

    def __init__(self, num_classes):

        self.num_classes = num_classes

    def __call__(self, target):

        return torch.nn.functional.one_hot(torch.tensor(target), num_classes=self.num_classes ).type(torch.float)

# %%
transform = torch.Tensor
target_transform = OneHotEncodeTransform(num_classes = 3)

# %%
train_path = './database/arrays.npy'
label_path = './database/labels.npy'

# %%
train_dataset = sleep_stages_dataset(train_path = train_path , label_path = label_path , transform = transform , target_transform = target_transform)

# %%
# Define the size of each split
train_size = int(0.8 * len(train_dataset))
validation_size = len(train_dataset) - train_size

# Split the dataset
train_dataset , validation_dataset = random_split(train_dataset, [train_size , validation_size])

train_loader = DataLoader(train_dataset , batch_size = 256 , shuffle = True , num_workers = 11 )
validation_loader = DataLoader(validation_dataset , batch_size = 256 , shuffle = False , num_workers = 11)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class encoder(nn.Module):

    def __init__(self , in_features , out_features):

        super().__init__()

        self.fc1 = nn.Linear(in_features, 7680)
        self.fc2 = nn.Linear(7680, 3840)
        self.fc3 = nn.Linear(3840, 1920)
        self.fc4 = nn.Linear(1920, 960)
        self.fc5 = nn.Linear(960, 480)
        self.fc6 = nn.Linear(480, out_features)

        self.batch_norm1 = nn.BatchNorm1d(7680)
        self.batch_norm2 = nn.BatchNorm1d(3840)
        self.batch_norm3 = nn.BatchNorm1d(1920)
        self.batch_norm4 = nn.BatchNorm1d(960)
        self.batch_norm5 = nn.BatchNorm1d(480)
        self.batch_norm6 = nn.BatchNorm1d(out_features)

        self.dropout = nn.Dropout(p = 0.2)

    def forward(self, x):

        x = F.relu(self.fc1(x))
        x = self.batch_norm1(x)
        x = self.dropout(x)

        x = F.relu(self.fc2(x))
        x = self.batch_norm2(x)
        x = self.dropout(x)

        x = F.relu(self.fc3(x))
        x = self.batch_norm3(x)
        x = self.dropout(x)

        x = F.relu(self.fc4(x))
        x = self.batch_norm4(x)
        x = self.dropout(x)

        x = F.relu(self.fc5(x))
        x = self.batch_norm5(x)
        x = self.dropout(x)

        x = F.relu(self.fc6(x))
        x = self.batch_norm6(x)
        x = self.dropout(x)

        return x

# %%
class decoder(nn.Module):

    def __init__(self , in_features , out_features):

        super().__init__()

        self.fc1 = nn.Linear(in_features, 480)
        self.fc2 = nn.Linear(480, 960)
        self.fc3 = nn.Linear(960, 1920)
        self.fc4 = nn.Linear(1920, 3840)
        self.fc5 = nn.Linear(3840, 7680)
        self.fc6 = nn.Linear(7680, out_features)

        self.batch_norm1 = nn.BatchNorm1d(480)
        self.batch_norm2 = nn.BatchNorm1d(960)
        self.batch_norm3 = nn.BatchNorm1d(1920)
        self.batch_norm4 = nn.BatchNorm1d(3840)
        self.batch_norm5 = nn.BatchNorm1d(7680)
        self.batch_norm6 = nn.BatchNorm1d(out_features)

        self.dropout = nn.Dropout(p = 0.2)

    def forward(self, x):

        x = F.relu(self.fc1(x))
        x = self.batch_norm1(x)
        x = self.dropout(x)

        x = F.relu(self.fc2(x))
        x = self.batch_norm2(x)
        x = self.dropout(x)

        x = F.relu(self.fc3(x))
        x = self.batch_norm3(x)
        x = self.dropout(x)

        x = F.relu(self.fc4(x))
        x = self.batch_norm4(x)
        x = self.dropout(x)

        x = F.relu(self.fc5(x))
        x = self.batch_norm5(x)
        x = self.dropout(x)

        x = F.relu(self.fc6(x))
        x = self.batch_norm6(x)
        x = self.dropout(x)

        return x

# %%
class autoencoder(L.LightningModule):

    def __init__(self , num_features):

        super().__init__()

        self.encoder = encoder(num_features , 240)
        self.decoder = decoder(240 , num_features)

    def forward (self , x) :

        x = self.encoder(x)
        x = self.decoder(x)

        return x

    def training_step(self, batch, batch_idx):

        x , y = batch

        y_hat = self(x.to(device))

        loss = F.cross_entropy(y_hat.squeeze() , x.to(device))

        self.log('train_loss', loss, on_step=True, on_epoch=True, prog_bar=True)

        return loss

    def validation_step(self, batch, batch_idx):

        x , y = batch

        y_hat = self(x)

        val_loss = F.cross_entropy(y_hat.squeeze(), x.to(device))

        self.log('val_loss', val_loss, on_step = True, on_epoch = True, prog_bar = True)

    def configure_optimizers(self):

        optimizer = torch.optim.AdamW(self.parameters(), lr = 1e-4)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 10, gamma=0.1)

        return [optimizer], [scheduler]

# %%
sleep_stages_autoencoder_model = autoencoder(num_features = 15360)

# %%
sleep_stages_autoencoder_model.to(device)
# Out:
# autoencoder(
#   (encoder): encoder(
#     (fc1): Linear(in_features=15360, out_features=7680, bias=True)
#     (fc2): Linear(in_features=7680, out_features=3840, bias=True)
#     (fc3): Linear(in_features=3840, out_features=1920, bias=True)
#     (fc4): Linear(in_features=1920, out_features=960, bias=True)
#     (fc5): Linear(in_features=960, out_features=480, bias=True)
#     (fc6): Linear(in_features=480, out_features=240, bias=True)
#     (batch_norm1): BatchNorm1d(7680, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batch_norm2): BatchNorm1d(3840, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batch_norm3): BatchNorm1d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batch_norm4): BatchNorm1d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batch_norm5): BatchNorm1d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batch_norm6): BatchNorm1d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.2, inplace=False)
#   )
#   (decoder): decoder(
#     (fc1): Linear(in_features=240, out_features=480, bias=True)
#     (fc2): Linear(in_features=480, out_features=960, bias=True)
#     (fc3): Linear(in_features=960, out_features=1920, bias=True)
#     (fc4): Linear(in_features=1920, out_features=3840, bias=True)
#     (fc5): Linear(in_features=3840, out_features=7680, bias=True)
#     (fc6): Linear(in_features=7680, out_features=15360, bias=True)
#     (batch_norm1): BatchNorm1d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batch_norm2): BatchNorm1d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batch_norm3): BatchNorm1d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batch_norm4): BatchNorm1d(3840, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batch_norm5): BatchNorm1d(7680, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batch_norm6): BatchNorm1d(15360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.2, inplace=False)
#   )
# )

# %%
checkpoint_callback = ModelCheckpoint(dirpath='./models'  , filename='autoencoder_{epoch}-{val_loss:.2f}')

# %%
trainer = L.Trainer(max_epochs = 100 , callbacks=[checkpoint_callback])
trainer.fit(model = sleep_stages_autoencoder_model, train_dataloaders = train_loader, val_dataloaders = validation_loader )
# Out:
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name    | Type    | Params | Mode
# --------------------------------------------
# 0 | encoder | encoder | 157 M  | train
# 1 | decoder | decoder | 157 M  | train
# --------------------------------------------
# 314 M     Trainable params
# 0         Non-trainable params
# 314 M     Total params
# 1,258.528 Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name    | Type    | Params | Mode
# --------------------------------------------
# 0 | encoder | encoder | 157 M  | train
# 1 | decoder | decoder | 157 M  | train
# --------------------------------------------
# 314 M     Trainable params
# 0         Non-trainable params
# 314 M     Total params
# 1,258.528 Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/call.py in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      43             return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 44         return trainer_fn(*args, **kwargs)
#      45
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/trainer.py in _fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     578         )
# --> 579         self._run(model, ckpt_path=ckpt_path)
#     580
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/trainer.py in _run(self, model, ckpt_path)
#     985         # ----------------------------
# --> 986         results = self._run_stage()
#     987
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/trainer.py in _run_stage(self)
#    1029             with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1030                 self.fit_loop.run()
#    1031             return None
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/loops/fit_loop.py in run(self)
#     205                 self.advance()
# --> 206                 self.on_advance_end()
#     207                 self._restarting = False
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/loops/fit_loop.py in on_advance_end(self)
#     377         call._call_lightning_module_hook(trainer, "on_train_epoch_end")
# --> 378         call._call_callback_hooks(trainer, "on_train_epoch_end", monitoring_callbacks=True)
#     379
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/call.py in _call_callback_hooks(trainer, hook_name, monitoring_callbacks, *args, **kwargs)
#     209             with trainer.profiler.profile(f"[Callback]{callback.state_key}.{hook_name}"):
# --> 210                 fn(trainer, trainer.lightning_module, *args, **kwargs)
#     211
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py in on_train_epoch_end(self, trainer, pl_module)
#     322             if self._every_n_epochs >= 1 and (trainer.current_epoch + 1) % self._every_n_epochs == 0:
# --> 323                 self._save_topk_checkpoint(trainer, monitor_candidates)
#     324             self._save_last_checkpoint(trainer, monitor_candidates)
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py in _save_topk_checkpoint(self, trainer, monitor_candidates)
#     384         else:
# --> 385             self._save_none_monitor_checkpoint(trainer, monitor_candidates)
#     386
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py in _save_none_monitor_checkpoint(self, trainer, monitor_candidates)
#     712         previous, self.best_model_path = self.best_model_path, filepath
# --> 713         self._save_checkpoint(trainer, filepath)
#     714
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py in _save_checkpoint(self, trainer, filepath)
#     387     def _save_checkpoint(self, trainer: "pl.Trainer", filepath: str) -> None:
# --> 388         trainer.save_checkpoint(filepath, self.save_weights_only)
#     389
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/trainer.py in save_checkpoint(self, filepath, weights_only, storage_options)
#    1369         checkpoint = self._checkpoint_connector.dump_checkpoint(weights_only)
# -> 1370         self.strategy.save_checkpoint(checkpoint, filepath, storage_options=storage_options)
#    1371         self.strategy.barrier("Trainer.save_checkpoint")
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/strategies/strategy.py in save_checkpoint(self, checkpoint, filepath, storage_options)
#     489         if self.is_global_zero:
# --> 490             self.checkpoint_io.save_checkpoint(checkpoint, filepath, storage_options=storage_options)
#     491
#
# /usr/local/lib/python3.10/dist-packages/lightning/fabric/plugins/io/torch_io.py in save_checkpoint(self, checkpoint, path, storage_options)
#      57         fs.makedirs(os.path.dirname(path), exist_ok=True)
# ---> 58         _atomic_save(checkpoint, path)
#      59
#
# /usr/local/lib/python3.10/dist-packages/lightning/fabric/utilities/cloud_io.py in _atomic_save(checkpoint, filepath)
#      79     with fsspec.open(filepath, "wb") as f:
# ---> 80         f.write(bytesbuffer.getvalue())
#      81
#
# /usr/local/lib/python3.10/dist-packages/fsspec/implementations/local.py in write(self, *args, **kwargs)
#     381     def write(self, *args, **kwargs):
# --> 382         return self.f.write(*args, **kwargs)
#     383
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-40-cf6e7fcca5b6> in <cell line: 2>()
#       1 trainer = L.Trainer(max_epochs = 100 , callbacks=[checkpoint_callback])
# ----> 2 trainer.fit(model = sleep_stages_autoencoder_model, train_dataloaders = train_loader, val_dataloaders = validation_loader )
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/trainer.py in fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     541         self.state.status = TrainerStatus.RUNNING
#     542         self.training = True
# --> 543         call._call_and_handle_interrupt(
#     544             self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     545         )
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/call.py in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      57             _interrupt(trainer, exception)
#      58     except BaseException as exception:
# ---> 59         _interrupt(trainer, exception)
#      60         trainer._teardown()
#      61         # teardown might access the stage so we reset it after
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/call.py in _interrupt(trainer, exception)
#      71     trainer.strategy.on_exception(exception)
#      72     for logger in trainer.loggers:
# ---> 73         logger.finalize("failed")
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/lightning_utilities/core/rank_zero.py in wrapped_fn(*args, **kwargs)
#      40             raise RuntimeError("The `rank_zero_only.rank` needs to be set before use")
#      41         if rank == 0:
# ---> 42             return fn(*args, **kwargs)
#      43         return default
#      44
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/loggers/tensorboard.py in finalize(self, status)
#     224     @rank_zero_only
#     225     def finalize(self, status: str) -> None:
# --> 226         super().finalize(status)
#     227         if status == "success":
#     228             # saving hparams happens independent of experiment manager
#
# /usr/local/lib/python3.10/dist-packages/lightning_utilities/core/rank_zero.py in wrapped_fn(*args, **kwargs)
#      40             raise RuntimeError("The `rank_zero_only.rank` needs to be set before use")
#      41         if rank == 0:
# ---> 42             return fn(*args, **kwargs)
#      43         return default
#      44
#
# /usr/local/lib/python3.10/dist-packages/lightning/fabric/loggers/tensorboard.py in finalize(self, status)
#     298         if self._experiment is not None:
#     299             self.experiment.flush()
# --> 300             self.experiment.close()
#     301
#     302     def _get_next_version(self) -> int:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/writer.py in close(self)
#    1261         for writer in self.all_writers.values():
#    1262             writer.flush()
# -> 1263             writer.close()
#    1264         self.file_writer = self.all_writers = None
#    1265
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/writer.py in close(self)
#     157         Call this method when you do not need the summary writer anymore.
#     158         """
# --> 159         self.event_writer.close()
#     160
#     161     def reopen(self):
#
# /usr/local/lib/python3.10/dist-packages/tensorboard/summary/writer/event_file_writer.py in close(self)
#     132         anymore.
#     133         """
# --> 134         self._async_writer.close()
#     135
#     136
#
# /usr/local/lib/python3.10/dist-packages/tensorboard/summary/writer/event_file_writer.py in close(self)
#     202                     self._worker.stop()
#     203                     self._writer.flush()
# --> 204                     self._writer.close()
#     205
#     206     def _check_worker_status(self):
#
# /usr/local/lib/python3.10/dist-packages/tensorboard/summary/writer/record_writer.py in close(self)
#      44
#      45     def close(self):
# ---> 46         self._writer.close()
#      47
#      48     @property
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/lib/io/file_io.py in close(self)
#     239     self._read_buf = None
#     240     if self._writable_file:
# --> 241       self._writable_file.close()
#     242       self._writable_file = None
#     243
#
# ResourceExhaustedError: /content/drive/MyDrive/SuperAI_SS4/Hackathons/SuperAI_SS4_Individual_Hackathon/Hack_Sleep_Stages_Classification/lightning_logs/version_5/events.out.tfevents.1718880383.0a982e20c433.275.2; No space left on device
