# %% [markdown]
# <a href="https://colab.research.google.com/github/xHexlabx/SuperAI_SS4_Recap/blob/main/SuperAI_SS4_Level_1/Pre_Diabetes_Prediction/Pre_Diabetes_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SuperAI Season 4 - Level 1 Hackathon - Pre Diabetes Prediction

# %% [markdown]
# ## Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Explore Datasets

# %%
import pandas as pd

# %%
train_df = pd.read_csv('/content/drive/MyDrive/SuperAI_SS4/Hackathons/SuperAI_SS4_Level_1/Pre_Diabetes_Prediction/datasets/train.csv' , index_col = 'ID')

# %%
test_df = pd.read_csv('/content/drive/MyDrive/SuperAI_SS4/Hackathons/SuperAI_SS4_Level_1/Pre_Diabetes_Prediction/datasets/test.csv' , index_col = 'ID')

# %%
train_df
# Out:
#      age  gender polyuria polydipsia sudden_weight_loss weakness polyphagia  \
# ID
# 0     41    Male      Yes         No                 No      Yes        Yes
# 1     45    Male       No         No                Yes      Yes        Yes
# 2     60    Male      Yes        Yes                Yes      Yes        Yes
# 3     66    Male      Yes        Yes                Yes      Yes         No
# 4     67    Male      Yes        Yes                 No      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 359   62  Female      Yes        Yes                Yes      Yes         No
# 360   39  Female      Yes        Yes                Yes       No        Yes
# 361   48  Female      Yes        Yes                Yes      Yes        Yes
# 362   58  Female      Yes        Yes                Yes      Yes        Yes
# 363   42    Male       No         No                 No       No         No
#
# ...

# %%
test_df
# Out:
#      age  gender polyuria polydipsia sudden_weight_loss weakness polyphagia  \
# ID
# 0     57    Male      Yes        Yes                Yes      Yes        Yes
# 1     55  Female      Yes        Yes                Yes      Yes         No
# 2     30    Male       No         No                 No       No         No
# 3     45  Female      Yes        Yes                Yes      Yes        Yes
# 4     47    Male       No         No                 No       No         No
# ..   ...     ...      ...        ...                ...      ...        ...
# 151   30    Male       No         No                 No       No         No
# 152   38    Male       No         No                 No       No         No
# 153   37    Male       No         No                 No       No         No
# 154   50  Female       No        Yes                Yes      Yes         No
# 155   40    Male       No        Yes                Yes      Yes         No
#
# ...

# %%
train_df.describe()
# Out:
#               age
# count  364.000000
# mean    47.848901
# std     12.255846
# min     16.000000
# 25%     38.000000
# 50%     47.000000
# 75%     56.000000
# max     90.000000

# %% [markdown]
# ## Import AutoGluon

# %%
# !python -m pip install --upgrade pip
# !python -m pip install autogluon

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
label = 'class'
print(f"Unique classes: {list(train_df[label].unique())}")
# Out:
# Unique classes: ['Positive', 'Negative']

# %%
predictor = TabularPredictor(label=label).fit(train_df)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20240526_135053"
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20240526_135053"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# ...

# %%
prediction = predictor.predict(test_df , model = 'ExtraTreesGini')

# %%
prediction
# Out:
# ID
# 0      Positive
# 1      Positive
# 2      Negative
# 3      Positive
# 4      Negative
#          ...
# 151    Negative
# 152    Negative
# 153    Negative
# 154    Positive
# 155    Negative
# Name: class, Length: 156, dtype: object

# %%
submission_path = '/content/drive/MyDrive/SuperAI_SS4/Hackathons/SuperAI_SS4_Level_1/Pre_Diabetes_Prediction/submissions'
prediction.to_csv(f'{submission_path}/submission.csv')
